# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from payoffs import forward_payoff

S = np.linspace(0, 200, 100)
K = 100
plt.plot(S, forward_payoff(S, K))

# %%
from payoffs import call_payoff

S = np.linspace(0, 200, 200)
K = 100

plt.figure(figsize=(6,4))
plt.plot(S, call_payoff(S, K))
plt.axvline(K, linestyle="--", alpha=0.5)
plt.title("European Call Payoff")
plt.xlabel("Underlying price $S_T$")
plt.ylabel("Payoff")
plt.grid(True)
plt.show()

# %%
from payoffs import put_payoff

S = np.linspace(0, 200, 200)
K = 100

plt.figure(figsize=(6,4))
plt.plot(S, put_payoff(S, K))
plt.axvline(K, linestyle="--", alpha=0.5)
plt.title("European Put Payoff")
plt.xlabel("Underlying price $S_T$")
plt.ylabel("Payoff")
plt.grid(True)
plt.show()

# %%
S = np.linspace(0, 200, 200)
K = 100

plt.figure(figsize=(7,5))

plt.plot(S, call_payoff(S, K), label="Call")
plt.plot(S, put_payoff(S, K), label="Put")
plt.plot(S, forward_payoff(S, K), linestyle="--", label="Forward")

plt.axvline(K, color="black", alpha=0.3)

plt.xlabel("Underlying price $S_T$")
plt.ylabel("Payoff")
plt.title("Option Payoffs vs Forward")
plt.legend()
plt.grid(True)
plt.show()
